# %% [markdown]
# # Bert Arabic Diacritization Pipeline (PyTorch)
#
# This notebook implements a character-level BiLSTM pipeline for Arabic text diacritization using PyTorch.
# Edit the `DATA_PATH` variables in the first code cell to point to your dataset.
#
# * The only actual input feature to the model is:
#
#         A 25-dimensional embedding vector representing each character.
#
# * For each position in the sequence:
#
#     1) Take the character ID (like "ل", "س", "و", <SPACE>, <NONAR>, etc.)
#
#     2) Convert it to a 25-dimensional vector using the embedding layer.
#
#     3) Feed these 25-dim vectors into the BiLSTM from left-to-right and right-to-left.
#
# * So the network learns:
#
#     1) context from characters before the position (forward LSTM)
#
#     2) context from characters after the position (backward LSTM)
#
#     Then it merges the two directions → a contextual representation of the character.
#
#     Finally, the model outputs a diacritic class for that timestep.
#
# * Arabic diacritization is context-dependent, e.g.
#
#     1) “عَلِمَ” vs “عُلِمَ” (vowel depends on verb form)
#
#     2) “في البيتِ” vs “في البيتُ” (case endings depend on grammar)
#
#     3) with Shadda or without depending on morphological assimilation
#
# * The BiLSTM captures these dependencies because:
#
#     1) embeddings encode the character identity
#
#     2) LSTM hidden states encode the sequence context

# %%
import os, glob, json
import unicodedata
from collections import Counter
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import math



device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)

DATA_PATH = '/kaggle/input/zftzft2/dataset/'
# DATA_PATH = 'dataset/'
TRAIN_FILE = os.path.join(DATA_PATH, 'train.txt')
VAL_FILE = os.path.join(DATA_PATH, 'val.txt')
OUTPUT_MODEL_PATH = '/kaggle/working/bert_diac_pytorch_with_der.pt'

# Hyperparameters
MAXLEN = 500
EMBED_DIM = 64        # Increased from 25 to 64 to support Multi-Head Attention (must be div by nhead)
NHEAD = 4             # Number of attention heads
NUM_LAYERS = 2        # Number of Transformer Encoder layers
FF_DIM = 256          # FeedForward dimension inside Transformer
DROPOUT = 0.1
BATCH_SIZE = 256
EPOCHS = 100

# Tokens
PLACEHOLDER = '<NONAR>'
PAD_TOKEN = '<PAD>'
SOS_TOKEN = '<SOS>'
EOS_TOKEN = '<EOS>'
UNK_TOKEN = '<UNK>'
SPACE_TOKEN = '<SPACE>'
# Out:
# Using device: cuda

# %%
# Check if a character is a combining diacritic
def is_combining(ch):
    return unicodedata.category(ch) == 'Mn'

# Split a string into (base_char, diacritics) pairs
def split_char_diacritic_pairs(s):
    pairs = []
    base = None
    diacs = ''
    for ch in s:
        if is_combining(ch):
            if base is None:
                base = '<UNK_BASE>'
            diacs += ch
        else:
            if base is not None:
                pairs.append((base, diacs))
            base = ch
            diacs = ''
    if base is not None:
        pairs.append((base, diacs))
    return pairs

# Check if a character is an Arabic letter
def is_arabic_letter(ch):
    if not isinstance(ch, str) or len(ch) != 1:
        return False
    code = ord(ch)
    return (
        (0x0600 <= code <= 0x06FF) or
        (0x0750 <= code <= 0x077F) or
        (0x08A0 <= code <= 0x08FF) or
        (0xFB50 <= code <= 0xFDFF) or
        (0xFE70 <= code <= 0xFEFF)
    )

# Transform (base_char, diacritics) pairs with placeholders
def placeholder_transform_pairs(pairs, placeholder=PLACEHOLDER):
    tokens = []
    labels = []
    for base, d in pairs:
        if isinstance(base, str) and base.startswith('<') and base.endswith('>'):
            tokens.append(base)
            labels.append('')
        elif base.isspace():
            tokens.append(SPACE_TOKEN)
            labels.append('')
        elif is_arabic_letter(base) or base == 'ـ':
            tokens.append(base)
            labels.append(d)
        else:
            tokens.append(placeholder)
            labels.append('')
    return tokens, labels

# %%
# Load train and val data
def load_lines_from_file(path):
    lines = []
    with open(path, 'r', encoding='utf8') as fh:
        for line in fh:
            s = line.strip()
            if s:
                lines.append(s)
    return lines

train_lines = load_lines_from_file(TRAIN_FILE) if os.path.exists(TRAIN_FILE) else []
val_lines = load_lines_from_file(VAL_FILE) if os.path.exists(VAL_FILE) else []
print('Train lines:', len(train_lines), 'Val lines:', len(val_lines))

train_tokens, train_labels = [], []
for line in train_lines:
    pairs = split_char_diacritic_pairs(line)
    toks, labs = placeholder_transform_pairs(pairs)
    train_tokens.append(toks)
    train_labels.append(labs)

val_tokens, val_labels = [], []
for line in val_lines:
    pairs = split_char_diacritic_pairs(line)
    toks, labs = placeholder_transform_pairs(pairs)
    val_tokens.append(toks)
    val_labels.append(labs)

print('Example tokens (first train line):', train_tokens[0][:60] if len(train_tokens)>0 else '---')
# Out:
# Train lines: 50000 Val lines: 2500
# Example tokens (first train line): ['و', 'ل', 'و', '<SPACE>', 'ج', 'م', 'ع', '<SPACE>', 'ث', 'م', '<SPACE>', 'ع', 'ل', 'م', '<SPACE>', 'ت', 'ر', 'ك', '<SPACE>', 'ر', 'ك', 'ن', '<SPACE>', 'م', 'ن', '<SPACE>', 'ا', 'ل', 'أ', 'و', 'ل', 'ى', '<SPACE>', 'ب', 'ط', 'ل', 'ت', 'ا', '<SPACE>', 'و', 'ي', 'ع', 'ي', 'د', 'ه', 'م', 'ا', '<SPACE>', 'ج', 'ا', 'م', 'ع', 'ا', '<SPACE>', '،', '<SPACE>', 'أ', 'و', '<SPACE>', 'م']

# %%
# Build vocabularies
char_counter = Counter(token for seq in (train_tokens + val_tokens) for token in seq)
special_chars = [PAD_TOKEN, SOS_TOKEN, EOS_TOKEN, UNK_TOKEN, SPACE_TOKEN, PLACEHOLDER]
single_chars = sorted([c for c in char_counter if len(c) == 1 and c not in special_chars])
multi_chars = sorted([c for c in char_counter if len(c) != 1 and c not in special_chars])
chars = special_chars + single_chars + multi_chars
char2idx = {c:i for i,c in enumerate(chars)}
idx2char = {i:c for c,i in char2idx.items()}

all_diacs = [d for lab in train_labels for d in lab]
diac_counter = Counter(all_diacs)
diac_classes = ['<PAD_LABEL>', '<NONE>']
most_common_diacs = [d for d,_ in diac_counter.most_common(13) if d != '']
for d in most_common_diacs:
    if d not in diac_classes:
        diac_classes.append(d)
diac_classes.append('<OTHER>')
diac2idx = {d:i for i,d in enumerate(diac_classes)}
idx2diac = {i:d for d,i in diac2idx.items()}

print('Vocab size:', len(char2idx), 'Diac labels:', len(diac2idx))
# Out:
# Vocab size: 45 Diac labels: 15

# %%
def map_diacritic_to_label(d):
    if d == '':
        return diac2idx['<NONE>']
    if d in diac2idx:
        return diac2idx[d]
    return diac2idx['<OTHER>']

def tokens_labels_to_ids(sequences_tokens, sequences_labels, maxlen=MAXLEN):
    X = []
    y = []
    for toks, labs in zip(sequences_tokens, sequences_labels):
        seq_mod = [SOS_TOKEN] + toks + [EOS_TOKEN]
        lab_mod = [''] + labs + ['']
        x_ids = [char2idx.get(t, char2idx[UNK_TOKEN]) for t in seq_mod]
        y_ids = [map_diacritic_to_label(d) for d in lab_mod]
        if len(x_ids) > maxlen:
            x_ids = x_ids[:maxlen]
            y_ids = y_ids[:maxlen]
        X.append(x_ids)
        y.append(y_ids)
    X_pad = []
    y_pad = []
    for seq_ids in X:
        if len(seq_ids) < maxlen:
            seq_ids = seq_ids + [char2idx[PAD_TOKEN]] * (maxlen - len(seq_ids))
        X_pad.append(seq_ids)
    for lab_ids in y:
        if len(lab_ids) < maxlen:
            lab_ids = lab_ids + [diac2idx['<PAD_LABEL>']] * (maxlen - len(lab_ids))
        y_pad.append(lab_ids)
    return np.array(X_pad, dtype=np.int64), np.array(y_pad, dtype=np.int64)

X_train_pad, y_train_pad = tokens_labels_to_ids(train_tokens, train_labels, MAXLEN)
X_val_pad, y_val_pad = tokens_labels_to_ids(val_tokens, val_labels, MAXLEN)
print('Shapes:', X_train_pad.shape, y_train_pad.shape, X_val_pad.shape, y_val_pad.shape)
# Out:
# Shapes: (50000, 500) (50000, 500) (2500, 500) (2500, 500)

# %%
class CharDiacDataset(Dataset):
    def __init__(self, X_arr, y_arr):
        self.X = X_arr
        self.y = y_arr
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return torch.tensor(self.X[idx], dtype=torch.long), torch.tensor(self.y[idx], dtype=torch.long)

def collate_pad(batch, pad_idx=0, pad_label_idx=0):
    Xs, Ys = zip(*batch)
    lengths = [x.size(0) for x in Xs]
    maxlen = max(lengths)
    Xp = torch.full((len(Xs), maxlen), pad_idx, dtype=torch.long)
    Yp = torch.full((len(Xs), maxlen), pad_label_idx, dtype=torch.long)
    for i,(x,y) in enumerate(zip(Xs,Ys)):
        Xp[i,:x.size(0)] = x
        Yp[i,:y.size(0)] = y
    return Xp, Yp, torch.tensor(lengths, dtype=torch.long)

train_dataset = CharDiacDataset(X_train_pad, y_train_pad)
val_dataset = CharDiacDataset(X_val_pad, y_val_pad)
X_train_pad = np.concatenate([X_train_pad, X_val_pad], axis=0)
y_train_pad = np.concatenate([y_train_pad, y_val_pad], axis=0)
train_loader = DataLoader(train_dataset, batch_size=min(64, len(train_dataset)), shuffle=True, collate_fn=lambda b: collate_pad(b, char2idx[PAD_TOKEN], diac2idx['<PAD_LABEL>']))
val_loader = DataLoader(val_dataset, batch_size=min(64, len(val_dataset)), shuffle=False, collate_fn=lambda b: collate_pad(b, char2idx[PAD_TOKEN], diac2idx['<PAD_LABEL>']))
print('Train batches:', len(train_loader), 'Val batches:', len(val_loader))
# Out:
# Train batches: 782 Val batches: 40

# %%
# Replace custom Transformer with a BERT encoder (HuggingFace) + projection head
# Note: if `transformers` is not installed, run: `!pip install transformers` in a notebook cell
try:
    from transformers import BertConfig, BertModel
except Exception:
    from transformers import BertConfig, BertModel

class Bert_Diac(nn.Module):
    def __init__(self, vocab_size, emb_dim, nhead, num_layers, ff_dim, num_labels, pad_idx, dropout=0.1):
        super().__init__()
        self.pad_idx = pad_idx

        # Build a small BERT config that matches our character-level setup
        config = BertConfig(
            vocab_size=vocab_size,
            hidden_size=emb_dim,
            num_attention_heads=nhead,
            num_hidden_layers=num_layers,
            intermediate_size=ff_dim,
            hidden_dropout_prob=dropout,
            attention_probs_dropout_prob=dropout,
            type_vocab_size=1,
            max_position_embeddings=MAXLEN+50,
            pad_token_id=pad_idx
        )

        # Initialize BERT from config (random init). Uses its own embeddings internally.
        self.bert = BertModel(config)

        # Projection to diacritic label space
        self.out = nn.Linear(config.hidden_size, num_labels)

    def forward(self, x, src_key_padding_mask=None):
        # x: [batch, seq_len] token ids
        attention_mask = (x != self.pad_idx).long()
        outputs = self.bert(input_ids=x, attention_mask=attention_mask)
        last_hidden = outputs.last_hidden_state
        logits = self.out(last_hidden)
        return logits
# Out:
# 2025-12-16 14:58:51.097187: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765897131.290549      20 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765897131.340600      20 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'

# %%
# Cell 8: Corrected Model Definition

# Ensure transformers is installed (uncomment if running in Colab/Kaggle and needed)
# !pip install transformers

import torch.nn as nn


from transformers import BertConfig, BertModel

class Bert_Diac(nn.Module):
    def __init__(self, vocab_size, emb_dim, nhead, num_layers, ff_dim, num_labels, pad_idx, dropout=0.1):
        super().__init__()
        self.pad_idx = pad_idx

        # Build BERT config
        config = BertConfig(
            vocab_size=vocab_size,
            hidden_size=emb_dim,       # Must be divisible by nhead
            num_attention_heads=nhead,
            num_hidden_layers=num_layers,
            intermediate_size=ff_dim,
            hidden_dropout_prob=dropout,
            attention_probs_dropout_prob=dropout,
            type_vocab_size=1,
            max_position_embeddings=MAXLEN + 50, # Ensures coverage for SOS/EOS
            pad_token_id=pad_idx
        )

        # Initialize BERT from scratch (Random Weights)
        self.bert = BertModel(config)

        # Projection to diacritic label space
        self.out = nn.Linear(config.hidden_size, num_labels)

    def forward(self, x, src_key_padding_mask=None):
        # x: [batch, seq_len] token ids
        
        # Create attention mask for BERT (1 for valid token, 0 for pad)
        # Note: We ignore the passed 'src_key_padding_mask' because BERT 
        # needs a specific 1/0 format which we calculate here.
        attention_mask = (x != self.pad_idx).long()
        
        # Pass to BERT
        outputs = self.bert(input_ids=x, attention_mask=attention_mask)
        
        # Get last hidden state
        last_hidden = outputs.last_hidden_state
        
        # Project to labels
        logits = self.out(last_hidden)
        return logits

# Instantiate the model
model = Bert_Diac(
    vocab_size=len(char2idx),
    emb_dim=EMBED_DIM,
    nhead=NHEAD,
    num_layers=NUM_LAYERS,
    ff_dim=FF_DIM,
    num_labels=len(diac2idx),
    pad_idx=char2idx[PAD_TOKEN],
    dropout=DROPOUT
).to(device)

# Define the pad label index explicitly for the Loss function
pad_label_idx = diac2idx['<PAD_LABEL>']

print(f"Model initialized and moved to {device}")
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.53.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.2.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers) (2024.2.0)
# Model initialized and moved to cuda

# %%
def train_epoch(model, dataloader, optimizer, criterion, device, grad_clip=None):
    model.train()
    total_loss = 0.0
    count = 0
    
    pad_idx = model.pad_idx # Access pad_idx stored in model
    
    for X, Y, lengths in dataloader:
        X = X.to(device)
        Y = Y.to(device)
        
        # Create Padding Mask for Transformer
        # Shape: [Batch, SeqLen], True where value is pad_idx
        mask = (X == pad_idx)
        
        optimizer.zero_grad()
        
        # Pass mask to forward
        logits = model(X, src_key_padding_mask=mask)
        
        # Reshape for Loss
        b, T, C = logits.shape
        logits_flat = logits.view(-1, C)
        labels_flat = Y.view(-1)
        
        loss = criterion(logits_flat, labels_flat)
        loss.backward()
        
        if grad_clip is not None:
            torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
            
        optimizer.step()
        total_loss += loss.item()
        count += 1
        
    return total_loss / max(1, count)

def eval_epoch(model, dataloader, criterion, device):
    model.eval()
    total_loss = 0.0
    count = 0
    correct = 0
    total = 0
    
    pad_idx = model.pad_idx
    
    with torch.no_grad():
        for X, Y, lengths in dataloader:
            X = X.to(device)
            Y = Y.to(device)
            
            # Create mask
            mask = (X == pad_idx)
            
            logits = model(X, src_key_padding_mask=mask)
            
            b, T, C = logits.shape
            logits_flat = logits.view(-1, C)
            labels_flat = Y.view(-1)
            
            loss = criterion(logits_flat, labels_flat)
            total_loss += loss.item()
            count += 1
            
            # Accuracy Calculation
            preds = logits.argmax(dim=-1)
            # We use the label pad index for masking accuracy, not input pad index
            valid_mask = (labels_flat != pad_label_idx) 
            
            correct += (preds.view(-1)[valid_mask] == labels_flat[valid_mask]).sum().item()
            total += valid_mask.sum().item()
            
    acc = correct / total if total > 0 else 0.0
    return total_loss / max(1, count), acc

# %%
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss(ignore_index=pad_label_idx)
best_val_loss = float('inf')
for epoch in range(1, EPOCHS + 1):
    tr_loss = train_epoch(model, train_loader, optimizer, criterion, device, grad_clip=5.0)
    val_loss, val_acc = eval_epoch(model, val_loader, criterion, device)
    print(f'Epoch {epoch} train_loss={tr_loss:.4f} val_loss={val_loss:.4f} val_acc={val_acc:.4f}')
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save({'model_state_dict': model.state_dict(), 'char2idx': char2idx, 'diac2idx': diac2idx}, OUTPUT_MODEL_PATH)
        print('Saved best model to', OUTPUT_MODEL_PATH)
# Out:
# Epoch 1 train_loss=0.9778 val_loss=0.9441 val_acc=0.6477
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 2 train_loss=0.9462 val_loss=0.9358 val_acc=0.6486
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 3 train_loss=0.9382 val_loss=0.9276 val_acc=0.6529
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 4 train_loss=0.9316 val_loss=0.9168 val_acc=0.6577
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 5 train_loss=0.8845 val_loss=0.7106 val_acc=0.7378
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 6 train_loss=0.6205 val_loss=0.4336 val_acc=0.8382
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 7 train_loss=0.4719 val_loss=0.3791 val_acc=0.8570
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 8 train_loss=0.4356 val_loss=0.3494 val_acc=0.8676
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 9 train_loss=0.4089 val_loss=0.3193 val_acc=0.8799
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 10 train_loss=0.3688 val_loss=0.2760 val_acc=0.8978
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 11 train_loss=0.3333 val_loss=0.2570 val_acc=0.9047
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 12 train_loss=0.3181 val_loss=0.2470 val_acc=0.9095
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 13 train_loss=0.3089 val_loss=0.2396 val_acc=0.9118
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 14 train_loss=0.3022 val_loss=0.2323 val_acc=0.9146
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 15 train_loss=0.2968 val_loss=0.2294 val_acc=0.9162
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 16 train_loss=0.2924 val_loss=0.2257 val_acc=0.9179
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 17 train_loss=0.2880 val_loss=0.2197 val_acc=0.9200
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 18 train_loss=0.2837 val_loss=0.2170 val_acc=0.9208
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 19 train_loss=0.2803 val_loss=0.2141 val_acc=0.9217
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 20 train_loss=0.2775 val_loss=0.2130 val_acc=0.9226
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 21 train_loss=0.2753 val_loss=0.2111 val_acc=0.9231
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 22 train_loss=0.2736 val_loss=0.2083 val_acc=0.9235
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 23 train_loss=0.2719 val_loss=0.2070 val_acc=0.9245
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 24 train_loss=0.2702 val_loss=0.2058 val_acc=0.9250
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 25 train_loss=0.2687 val_loss=0.2054 val_acc=0.9250
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 26 train_loss=0.2677 val_loss=0.2034 val_acc=0.9255
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 27 train_loss=0.2666 val_loss=0.2020 val_acc=0.9261
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 28 train_loss=0.2655 val_loss=0.2013 val_acc=0.9267
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 29 train_loss=0.2645 val_loss=0.2008 val_acc=0.9264
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 30 train_loss=0.2635 val_loss=0.1999 val_acc=0.9267
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 31 train_loss=0.2626 val_loss=0.1986 val_acc=0.9271
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 32 train_loss=0.2621 val_loss=0.1980 val_acc=0.9281
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 33 train_loss=0.2612 val_loss=0.1984 val_acc=0.9274
# Epoch 34 train_loss=0.2606 val_loss=0.1976 val_acc=0.9279
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 35 train_loss=0.2599 val_loss=0.1962 val_acc=0.9289
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 36 train_loss=0.2593 val_loss=0.1953 val_acc=0.9289
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 37 train_loss=0.2585 val_loss=0.1959 val_acc=0.9288
# Epoch 38 train_loss=0.2580 val_loss=0.1937 val_acc=0.9293
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 39 train_loss=0.2578 val_loss=0.1947 val_acc=0.9292
# Epoch 40 train_loss=0.2570 val_loss=0.1933 val_acc=0.9295
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 41 train_loss=0.2563 val_loss=0.1924 val_acc=0.9300
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 42 train_loss=0.2561 val_loss=0.1926 val_acc=0.9299
# Epoch 43 train_loss=0.2553 val_loss=0.1914 val_acc=0.9301
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 44 train_loss=0.2551 val_loss=0.1937 val_acc=0.9295
# Epoch 45 train_loss=0.2544 val_loss=0.1910 val_acc=0.9303
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 46 train_loss=0.2542 val_loss=0.1913 val_acc=0.9306
# Epoch 47 train_loss=0.2538 val_loss=0.1916 val_acc=0.9305
# Epoch 48 train_loss=0.2536 val_loss=0.1909 val_acc=0.9307
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 49 train_loss=0.2531 val_loss=0.1903 val_acc=0.9309
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 50 train_loss=0.2526 val_loss=0.1892 val_acc=0.9312
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 51 train_loss=0.2524 val_loss=0.1897 val_acc=0.9310
# Epoch 52 train_loss=0.2521 val_loss=0.1910 val_acc=0.9303
# Epoch 53 train_loss=0.2516 val_loss=0.1902 val_acc=0.9308
# Epoch 54 train_loss=0.2515 val_loss=0.1893 val_acc=0.9309
# Epoch 55 train_loss=0.2512 val_loss=0.1888 val_acc=0.9315
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 56 train_loss=0.2510 val_loss=0.1888 val_acc=0.9314
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 57 train_loss=0.2505 val_loss=0.1877 val_acc=0.9319
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 58 train_loss=0.2503 val_loss=0.1871 val_acc=0.9318
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 59 train_loss=0.2499 val_loss=0.1881 val_acc=0.9317
# Epoch 60 train_loss=0.2497 val_loss=0.1876 val_acc=0.9317
# Epoch 61 train_loss=0.2497 val_loss=0.1885 val_acc=0.9315
# Epoch 62 train_loss=0.2492 val_loss=0.1875 val_acc=0.9321
# Epoch 63 train_loss=0.2490 val_loss=0.1869 val_acc=0.9322
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 64 train_loss=0.2485 val_loss=0.1880 val_acc=0.9315
# Epoch 65 train_loss=0.2485 val_loss=0.1867 val_acc=0.9318
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 66 train_loss=0.2481 val_loss=0.1874 val_acc=0.9319
# Epoch 67 train_loss=0.2482 val_loss=0.1868 val_acc=0.9319
# Epoch 68 train_loss=0.2478 val_loss=0.1862 val_acc=0.9320
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 69 train_loss=0.2480 val_loss=0.1862 val_acc=0.9322
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 70 train_loss=0.2474 val_loss=0.1878 val_acc=0.9317
# Epoch 71 train_loss=0.2468 val_loss=0.1883 val_acc=0.9315
# Epoch 72 train_loss=0.2470 val_loss=0.1853 val_acc=0.9323
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 73 train_loss=0.2468 val_loss=0.1853 val_acc=0.9326
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 74 train_loss=0.2465 val_loss=0.1852 val_acc=0.9325
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 75 train_loss=0.2465 val_loss=0.1856 val_acc=0.9326
# Epoch 76 train_loss=0.2461 val_loss=0.1841 val_acc=0.9333
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 77 train_loss=0.2458 val_loss=0.1855 val_acc=0.9328
# Epoch 78 train_loss=0.2457 val_loss=0.1838 val_acc=0.9328
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 79 train_loss=0.2456 val_loss=0.1842 val_acc=0.9333
# Epoch 80 train_loss=0.2450 val_loss=0.1856 val_acc=0.9325
# Epoch 81 train_loss=0.2451 val_loss=0.1837 val_acc=0.9333
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 82 train_loss=0.2449 val_loss=0.1829 val_acc=0.9334
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 83 train_loss=0.2447 val_loss=0.1838 val_acc=0.9332
# Epoch 84 train_loss=0.2445 val_loss=0.1846 val_acc=0.9330
# Epoch 85 train_loss=0.2444 val_loss=0.1832 val_acc=0.9335
# Epoch 86 train_loss=0.2443 val_loss=0.1846 val_acc=0.9331
# Epoch 87 train_loss=0.2439 val_loss=0.1832 val_acc=0.9336
# Epoch 88 train_loss=0.2437 val_loss=0.1838 val_acc=0.9335
# Epoch 89 train_loss=0.2437 val_loss=0.1836 val_acc=0.9335
# Epoch 90 train_loss=0.2436 val_loss=0.1832 val_acc=0.9338
# Epoch 91 train_loss=0.2433 val_loss=0.1827 val_acc=0.9339
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 92 train_loss=0.2431 val_loss=0.1829 val_acc=0.9339
# Epoch 93 train_loss=0.2429 val_loss=0.1823 val_acc=0.9342
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 94 train_loss=0.2430 val_loss=0.1819 val_acc=0.9339
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 95 train_loss=0.2427 val_loss=0.1813 val_acc=0.9342
# Saved best model to /kaggle/working/bert_diac_pytorch_with_der.pt
# Epoch 96 train_loss=0.2425 val_loss=0.1828 val_acc=0.9338
# Epoch 97 train_loss=0.2425 val_loss=0.1829 val_acc=0.9333
# Epoch 98 train_loss=0.2421 val_loss=0.1829 val_acc=0.9342
# Epoch 99 train_loss=0.2422 val_loss=0.1817 val_acc=0.9343
# Epoch 100 train_loss=0.2420 val_loss=0.1830 val_acc=0.9337

# %%
def predict_on_loader_collect(model, loader, device):
    model.eval()
    Xs, Ys, Ypreds = [], [], []
    pad_idx = model.pad_idx
    
    with torch.no_grad():
        for X_batch, y_batch, lengths in loader:
            X_batch = X_batch.to(device)
            
            # Generate mask
            mask = (X_batch == pad_idx)
            
            # Pass mask
            logits = model(X_batch, src_key_padding_mask=mask)
            
            pred_ids = logits.argmax(dim=-1).cpu().numpy()
            Xs.append(X_batch.cpu().numpy())
            Ys.append(y_batch.numpy())
            Ypreds.append(pred_ids)
            
    if len(Xs) == 0:
        return None, None, None
    X_all = np.vstack(Xs)
    Y_true_all = np.vstack(Ys)
    Y_pred_all = np.vstack(Ypreds)
    return X_all, Y_true_all, Y_pred_all

# %%
def compute_der_from_arrays(X_pad, y_true_pad, y_pred_pad, char2idx, diac2idx, idx2diac, exclude_case_ending=False):
    pad_label_id = diac2idx["<PAD_LABEL>"]
    pad_char_id = char2idx[PAD_TOKEN]
    sos_id = char2idx.get(SOS_TOKEN, None)
    eos_id = char2idx.get(EOS_TOKEN, None)
    space_id = char2idx.get(SPACE_TOKEN, None)
    placeholder_id = char2idx.get(PLACEHOLDER, None)

    N, T = X_pad.shape
    total = 0
    incorrect = 0

    for i in range(N):
        for t in range(T):
            ch_id = int(X_pad[i, t])
            if ch_id == pad_char_id:
                break
            if sos_id is not None and ch_id == sos_id:
                continue
            if eos_id is not None and ch_id == eos_id:
                continue

            gold = int(y_true_pad[i, t])
            if gold == pad_label_id:
                continue

            if exclude_case_ending:
                next_id = pad_char_id
                if t + 1 < T:
                    next_id = int(X_pad[i, t+1])
                is_word_final = False
                if next_id == pad_char_id:
                    is_word_final = True
                elif space_id is not None and next_id == space_id:
                    is_word_final = True
                elif placeholder_id is not None and next_id == placeholder_id:
                    is_word_final = True
                elif eos_id is not None and next_id == eos_id:
                    is_word_final = True

                if is_word_final:
                    continue

            pred = int(y_pred_pad[i, t])
            total += 1
            if pred != gold:
                incorrect += 1

    der = (incorrect / total) * 100.0 if total > 0 else None
    return der, incorrect, total

def evaluate_with_der(model, loader, device, name="validation"):
    try:
        val_loss, val_acc = eval_epoch(model, loader, criterion, device)
    except Exception:
        val_loss, val_acc = None, None

    X_all, y_true_all, y_pred_all = predict_on_loader_collect(model, loader, device)
    if X_all is None:
        print(f"No data found in {name} loader.")
        return

    none_id = diac2idx.get("<NONE>", None)
    if none_id is not None:
        gold_non_none = (y_true_all != none_id).sum()
        if gold_non_none == 0:
            print(f"Dataset in {name} loader appears to have NO gold diacritics (all labels are <NONE>).")
            print("DER cannot be computed for this loader. You can still compute accuracy if desired.")
            if val_acc is not None:
                print(f"Label-level accuracy (existing): {val_acc:.4f}")
            return

    der_all, incorrect_all, total_all = compute_der_from_arrays(
        X_all, y_true_all, y_pred_all, char2idx, diac2idx, idx2diac, exclude_case_ending=False
    )
    der_no_ce, incorrect_no_ce, total_no_ce = compute_der_from_arrays(
        X_all, y_true_all, y_pred_all, char2idx, diac2idx, idx2diac, exclude_case_ending=True
    )

    header = f"Evaluation on {name} set"
    print("="*len(header))
    print(header)
    print("="*len(header))
    if val_loss is not None:
        print(f"Label-level loss: {val_loss:.4f}")
    if val_acc is not None:
        print(f"Label-level accuracy (existing metric): {val_acc:.4f}")
    print(f"DER (all positions): {der_all:.4f}%   ({incorrect_all} incorrect / {total_all} total positions)")
    print(f"DER (no case ending): {der_no_ce:.4f}%   ({incorrect_no_ce} incorrect / {total_no_ce} total positions)")
    print()

# Example usage (after training): evaluate on validation and test
try:
    evaluate_with_der(model, val_loader, device, name='validation')
except NameError:
    print('val_loader or model not found in this notebook context; run training cells first, then run this cell.')

# try:
#     evaluate_with_der(model, test_loader, device, name='test')
# except NameError:
#     pass
# Out:
# ============================
# Evaluation on validation set
# ============================
# Label-level loss: 0.1830
# Label-level accuracy (existing metric): 0.9337
# DER (all positions): 6.6987%   (31568 incorrect / 471258 total positions)
# DER (no case ending): 4.9761%   (17587 incorrect / 353427 total positions)
